# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage import color, exposure
import seaborn as sns

from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import jaccard_score

from sklearn.cluster import KMeans
from collections import Counter
import skimage.morphology

# %%
def read_data(data_path, data_type):
    if data_type == 'before':
        data_path = os.path.join(data_path, 'A')
    elif data_type == 'after':
        data_path = os.path.join(data_path, 'B')
    elif data_type == 'label':
        data_path = os.path.join(data_path, 'label')
    else:
        print('data_type is not correct')
        return None

    data = []
    for file in os.listdir(data_path):
        img = cv2.imread(os.path.join(data_path, file))
        data.append(img)
    return data

# display images {before, after, labels}
def display_images(before, after, labels):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    axs[0].imshow(cv2.cvtColor(before, cv2.COLOR_BGR2RGB))
    axs[0].set_title('Before')
    axs[0].axis('off')
    axs[1].imshow(cv2.cvtColor(after, cv2.COLOR_BGR2RGB))
    axs[1].set_title('After')
    axs[1].axis('off')
    axs[2].imshow(labels, cmap='gray')
    axs[2].set_title('Labels')
    axs[2].axis('off')
    plt.show()

# %%
def plot_row(images, titles):
    fig, ax = plt.subplots(1, len(images), figsize=(10, 20))
    ax[0].imshow(images[0].astype("uint8"))
    ax[0].set_title(titles[0])
    ax[0].axis("off")
    for i in range(len(images) - 1):
        ax[i+1].imshow(images[i + 1])
        ax[i+1].set_title(titles[i + 1])
        ax[i+1].axis("off")
    plt.tight_layout()
    plt.show()

# %%
training_path = '../trainval/'

# %%
before_images = read_data(training_path,'before')
after_images = read_data(training_path, 'after')
labels = read_data(training_path,'label')

# %%
index = 0
# print first image in before_images, after_images, and labels in the same row
display_images(before_images[index], after_images[index], labels[index])

# %% [markdown]
# ## PCA with Kmeans

# %%
def find_vector_set(diff_image, new_size):
    i = 0
    j = 0
    vector_set = np.zeros((int(new_size[0] * new_size[1] / 25),25))
    while i < vector_set.shape[0]:
        while j < new_size[1]:
            k = 0
            while k < new_size[0]:
                block   = diff_image[j:j+5, k:k+5]
                feature = block.ravel()
                vector_set[i, :] = feature
                k = k + 5
            j = j + 5
        i = i + 1

    mean_vec   = np.mean(vector_set, axis = 0)
    # Mean normalization
    vector_set = vector_set - mean_vec   
    return vector_set, mean_vec

# %%
def find_FVS(EVS, diff_image, mean_vec, new):
    i = 2
    feature_vector_set = []
    while i < new[1] - 2:
        j = 2
        while j < new[0] - 2:
            block = diff_image[i-2:i+3, j-2:j+3]
            feature = block.flatten()
            feature_vector_set.append(feature)
            j = j+1
        i = i+1
 
    FVS = np.dot(feature_vector_set, EVS)
    FVS = FVS - mean_vec
    print("[INFO] Feature vector space size", FVS.shape)
    return FVS

# %%
def clustering(FVS, components, new):
    kmeans = KMeans(components, verbose=0)
    kmeans.fit(FVS)
    output = kmeans.predict(FVS)
    count = Counter(output)
 
    least_index = min(count, key=count.get)
    change_map = np.reshape(output,(new[1] - 4, new[0] - 4))
    return least_index, change_map

# %%
# Define the output directory
out_dir = "output"

# Check if the output directory exists, if not, create it
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# %%
import matplotlib.pyplot as plt

# display images {before, after, labels, predicted_label}
def display_images(before, after, labels, predicted_label):
    # Convert images to uint8
    before = before.astype(np.uint8)
    after = after.astype(np.uint8)
    labels = labels.astype(np.uint8)
    predicted_label = predicted_label.astype(np.uint8)

    fig, axs = plt.subplots(1, 4, figsize=(20, 5))
    axs[0].imshow(cv2.cvtColor(before, cv2.COLOR_BGR2RGB))
    axs[0].set_title('Before')
    axs[0].axis('off')
    axs[1].imshow(cv2.cvtColor(after, cv2.COLOR_BGR2RGB))
    axs[1].set_title('After')
    axs[1].axis('off')
    axs[2].imshow(labels, cmap='gray')
    axs[2].set_title('Labels')
    axs[2].axis('off')
    axs[3].imshow(predicted_label, cmap='gray')
    axs[3].set_title('Predicted Labels')
    axs[3].axis('off')
    plt.show()

# %%
def increase_saturation(before_images, after_images, factor):
    """
    Increases the saturation of an image using the HSV color space.

    Args:
    - image: NumPy array representing the image (RGB).
    - factor: Factor to increase the saturation by.

    Returns:
    - image: NumPy array representing the image with increased saturation (RGB).
    """
    preprocessed_images_A = []
    preprocessed_images_B = []

    for image_A, image_B in zip(before_images, after_images):
        # Convert the image to the HSV color space
        hsv_image_A = color.rgb2hsv(image_A)
        hsv_image_B = color.rgb2hsv(image_B)

        # Increase the saturation
        hsv_image_A[:, :, 1] *= factor
        hsv_image_B[:, :, 1] *= factor

        # convert to RGB
        enhanced_image_A = color.hsv2rgb(hsv_image_A)
        enhanced_image_B = color.hsv2rgb(hsv_image_B)

        # multiply by 255
        enhanced_image_A = (enhanced_image_A * 255).astype(np.uint8)
        enhanced_image_B = (enhanced_image_B * 255).astype(np.uint8)

        # Append preprocessed images to the list
        preprocessed_images_A.append(enhanced_image_A)
        preprocessed_images_B.append(enhanced_image_B)

    return preprocessed_images_A, preprocessed_images_B

# factor: 1.5 is best

# %%
def preprocess_images(before_images, after_images, gamma_values):
    """
    Preprocesses a list of before and after satellite images using gamma correction.

    Args:
    - before_images: List of NumPy arrays representing the before images (RGB).
    - after_images: List of NumPy arrays representing the after images (RGB).
    - gamma_values: List of gamma values to apply for gamma correction.

    Returns:
    - preprocessed_images_A: List of preprocessed before images.
    - preprocessed_images_B: List of preprocessed after images.
    """
    preprocessed_images_A = []
    preprocessed_images_B = []

    for gamma in gamma_values:
        for image_A, image_B in zip(before_images, after_images):

            # Gamma Correction
            corrected_image_A = exposure.adjust_gamma(image_A, gamma)
            corrected_image_B = exposure.adjust_gamma(image_B, gamma)
            
            # Append preprocessed images to the list
            preprocessed_images_A.append(corrected_image_A)
            preprocessed_images_B.append(corrected_image_B)

    return preprocessed_images_A, preprocessed_images_B

# best is 1.1

# %%
def calculate_iou(mask1, mask2):
    intersection = np.logical_and(mask1, mask2)
    union = np.logical_or(mask1, mask2)
    iou_score = np.sum(intersection) / np.sum(union)
    return iou_score

# %%
# Define the number of images to process
num_images = min(1800, len(before_images))

# Iterate over pairs of images and apply change detection
iou_scores = []
for i in range(4000):
    # Apply change detection code here for each pair of images
    image1 = before_images[i]
    image2 = after_images[i]
    label = labels[i]

    # Resize Images
    new_size = np.asarray(image1.shape) // 5
    new_size = new_size * 5
    image1_resized = cv2.resize(image1, (new_size[1], new_size[0])).astype(float)
    image2_resized = cv2.resize(image2, (new_size[1], new_size[0])).astype(float)

    # Difference Image
    diff_image = np.mean(np.abs(image1_resized - image2_resized), axis=2)  # Average of RGB channels

    # Performing PCA
    pca = PCA()
    vector_set, mean_vec = find_vector_set(diff_image, new_size)
    pca.fit(vector_set)
    EVS = pca.components_

    # Building Feature Vector Space
    FVS = find_FVS(EVS, diff_image, mean_vec, new_size)
    components = 3

    # Clustering
    least_index, change_map = clustering(FVS, components, new_size)

    # Post-processing change map
    change_map[change_map == least_index] = 255
    change_map[change_map != 255] = 0
    change_map = change_map.astype(np.uint8)

    # Resize label to match the dimensions of change_map
    label_resized = cv2.resize(label, (change_map.shape[1], change_map.shape[0]))

    # Convert label to binary mask
    label_binary = label_resized > 0
    label_binary = cv2.cvtColor(label_binary.astype(np.uint8), cv2.COLOR_BGR2GRAY)  # Convert to grayscale

    # Invert the binary masks
    change_map_inverted = np.logical_not(change_map)
    label_binary_inverted = np.logical_not(label_binary)

    # Calculate Jaccard index (IOU) using built-in method
    intersection = np.logical_and(change_map_inverted, label_binary_inverted)
    union = np.logical_or(change_map_inverted, label_binary_inverted)
    iou = np.sum(intersection) / np.sum(union)

    # Append IOU score to the list
    iou_scores.append(iou)
    
    # Print Jaccard index for each pair
    print(f'Jaccard index (IOU) for pair {i}: {iou}')
# Out:
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 0: 0.7619357604432943
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 1: 0.730731256767947
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 2: 0.7041233313568693
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3: 0.8296762044587715
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 4: 0.7927493214393422
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 5: 0.7760511737908922
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 6: 0.805907842732655
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 7: 0.8698750813479151
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 8: 0.8828431294741353
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 9: 0.7581926672835764
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 10: 0.7927045075125209
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 11: 0.7615117220361581
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 12: 0.787612323491656
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 13: 0.8325418525447307
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 14: 0.8655576895604832
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 15: 0.696494690655227
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 16: 0.7720713410656611
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 17: 0.8645894509610959
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 18: 0.8509063762800435
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 19: 0.8710077223758222
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 20: 0.7500565665707729
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 21: 0.7648401826484018
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 22: 0.7515215450783088
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 23: 0.8324547702720292
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 24: 0.6875596715676914
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 25: 0.8269756292449061
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 26: 0.7642735829590006
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 27: 0.8137331130333366
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 28: 0.8102019432272813
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 29: 0.7220361581562197
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 30: 0.7099049858590994
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 31: 0.816400534385139
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 32: 0.8418913985492293
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 33: 0.7773686131966159
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 34: 0.7605752289646196
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 35: 0.6980067694622039
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 36: 0.7832636538589156
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 37: 0.7516128497271838
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 38: 0.6832215645444261
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 39: 0.7979894528675017
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 40: 0.7802698116694387
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 41: 0.7898891063274625
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 42: 0.7229885239916827
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 43: 0.7994158822875828
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 44: 0.6976736682476689
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 45: 0.8230980460627609
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 46: 0.7432421707591943
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 47: 0.7380517769559213
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 48: 0.7322423453595974
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 49: 0.7256234028031301
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 50: 0.7107982412977571
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 51: 0.7640283426537875
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 52: 0.7278435392673511
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 53: 0.8718068560929618
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 54: 0.7949157655726512
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 55: 0.8659680352186813
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 56: 0.7284487547816701
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 57: 0.7646227837653371
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3941: 0.7840140116232784
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3942: 0.7893727380376591
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3943: 0.6733040018116528
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3944: 0.6556886709013428
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3945: 0.604494382022472
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3946: 0.628696359893398
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3947: 0.8203508214937694
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3948: 0.774994727706309
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3949: 0.6218654360749251
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3950: 0.7255095227496741
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3951: 0.7687348009727377
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3952: 0.6471987610365143
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3953: 0.6606113452502059
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3954: 0.65253873659118
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3955: 0.7657648843011594
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3956: 0.6705734550427785
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3957: 0.7986931872777938
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3958: 0.645319876281947
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3959: 0.7603961684203678
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3960: 0.7845755178390623
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3961: 0.6516686436059372
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3962: 0.6162813164165647
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3963: 0.774273366663842
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3964: 0.7338535178021114
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3965: 0.6665099158410223
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3966: 0.7699251575630253
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3967: 0.7017203532594823
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3968: 0.7600847903351768
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3969: 0.7198093666324246
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3970: 0.6860155661561637
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3971: 0.8024950337703616
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3972: 0.7945090844719097
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3973: 0.7962294424388288
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3974: 0.7476229813563989
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3975: 0.7373843227033825
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3976: 0.6672074049334414
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3977: 0.6810478149264202
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3978: 0.6911584930223696
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3979: 0.7003696313499722
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3980: 0.7340898976412995
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3981: 0.8442989780241801
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3982: 0.8457160596026491
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3983: 0.6909103772750588
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3984: 0.8503204564706635
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3985: 0.7871202018092132
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3986: 0.8300100672230701
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3987: 0.8385881515974648
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3988: 0.7835313520245027
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3989: 0.6809882384300137
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3990: 0.7374600984905599
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3991: 0.706351765274867
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3992: 0.7243727656545722
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3993: 0.8744763564462616
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3994: 0.8820542862722125
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3995: 0.9058030661590699
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3996: 0.8407888722000915
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3997: 0.691926672718875
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3998: 0.8028261307883594
# [INFO] Feature vector space size (63001, 25)
# Jaccard index (IOU) for pair 3999: 0.7643158019386599

# %%
# Calculate mean Jaccard index
mean_iou = np.mean(iou_scores)
print(f'Mean Jaccard index (IOU) for the first 5 pairs: {mean_iou}')

print('Change detection for the first 5 pairs completed.')
# Out:
# Mean Jaccard index (IOU) for the first 5 pairs: 0.8687654118012224
# Change detection for the first 5 pairs completed.

# %%
# Iterate over pairs of images and apply change detection
for i in range(len(before_images)):
    # Apply change detection code here for each pair of images
    image1 = before_images[i]
    image2 = after_images[i]
    label = labels[i]

    # Resize Images
    new_size = np.asarray(image1.shape) // 5
    new_size = new_size * 5
    image1_resized = cv2.resize(image1, (new_size[1], new_size[0])).astype(float)
    image2_resized = cv2.resize(image2, (new_size[1], new_size[0])).astype(float)

    # Difference Image
    diff_image = np.abs(image1_resized - image2_resized)
    diff_image = diff_image[:, :, 1]  # Assuming images are in BGR format and taking green channel

    # Performing PCA
    pca = PCA()
    vector_set, mean_vec = find_vector_set(diff_image, new_size)
    pca.fit(vector_set)
    EVS = pca.components_

    # Building Feature Vector Space
    FVS = find_FVS(EVS, diff_image, mean_vec, new_size)
    components = 3

    # Clustering
    least_index, change_map = clustering(FVS, components, new_size)

    # Post-processing change map
    change_map[change_map == least_index] = 255
    change_map[change_map != 255] = 0
    change_map = change_map.astype(np.uint8)

    # Save Change Map
    cv2.imwrite(os.path.join(out_dir, f'ChangeMap_{i}.jpg'), change_map)

    # Performing Closing
    kernel = skimage.morphology.disk(6)
    CloseMap = cv2.morphologyEx(change_map, cv2.MORPH_CLOSE, kernel)
    cv2.imwrite(os.path.join(out_dir, f'CloseMap_{i}.jpg'), CloseMap)

    # Performing Opening
    OpenMap = cv2.morphologyEx(CloseMap, cv2.MORPH_OPEN, kernel)
    cv2.imwrite(os.path.join(out_dir, f'OpenMap_{i}.jpg'), OpenMap)

    print(f'Change detection completed for pair {i}')

print('Change detection for all pairs completed.')
# Out:
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 0
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 1
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 2
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 3
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 4
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 5
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 6
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 7
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 8
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 9
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 10
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 11
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 12
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 13
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 14
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 15
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 16
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 17
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 18
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 19
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 20
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 21
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 22
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 23
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 24
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 25
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 26
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 27
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 28
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 29
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 30
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 31
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 32
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 33
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 34
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 35
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 36
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 37
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 38
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 39
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 40
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 41
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 42
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 43
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 44
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 45
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 46
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 47
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 48
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 49
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 50
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 51
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 52
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 53
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 54
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 55
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 56
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 57
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 58
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 59
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 60
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 61
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 62
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 63
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 64
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 65
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 66
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 67
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 68
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 69
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 70
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 71
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 72
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 73
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 74
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 75
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 76
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 77
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 78
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 79
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 80
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 81
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 82
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 83
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 84
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 85
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 86
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 87
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 88
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 89
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 90
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 91
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 92
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 93
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 94
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 95
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 96
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 97
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 98
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 99
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 100
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 101
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 102
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 103
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 104
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 105
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 106
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 107
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 108
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 109
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 110
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 111
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 112
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 113
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 114
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 115
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 116
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 117
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 118
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 119
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 120
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 121
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 122
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 123
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 124
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 125
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 126
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 127
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 128
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 129
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 130
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 131
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 132
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 133
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 134
# [INFO] Feature vector space size (63001, 25)
# Change detection completed for pair 135
# [INFO] Feature vector space size (63001, 25)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [27], in <module>
#      26 components = 3
#      28 # Clustering
# ---> 29 least_index, change_map = clustering(FVS, components, new_size)
#      31 # Post-processing change map
#      32 change_map[change_map == least_index] = 255
#
# Input In [24], in clustering(FVS, components, new)
#       1 def clustering(FVS, components, new):
#       2     kmeans = KMeans(components, verbose=0)
# ----> 3     kmeans.fit(FVS)
#       4     output = kmeans.predict(FVS)
#       5     count = Counter(output)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1481, in KMeans.fit(self, X, y, sample_weight)
#    1453 @_fit_context(prefer_skip_nested_validation=True)
#    1454 def fit(self, X, y=None, sample_weight=None):
#    1455     """Compute k-means clustering.
#    1456
#    1457     Parameters
#    (...)
#    1479         Fitted estimator.
#    1480     """
# -> 1481     X = self._validate_data(
#    1482         X,
#    1483         accept_sparse="csr",
#    1484         dtype=[np.float64, np.float32],
#    1485         order="C",
#    1486         copy=self.copy_x,
#    1487         accept_large_sparse=False,
#    1488     )
#    1490     self._check_params_vs_input(X)
#    1492     random_state = check_random_state(self.random_state)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:122, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 # First try an O(n) time, O(1) space solution for the common case that
#     118 # everything is finite; fall back to O(n) space `np.isinf/isnan` or custom
#     119 # Cython implementation to prevent false positives and provide a detailed
#     120 # error message.
#     121 with np.errstate(over="ignore"):
# --> 122     first_pass_isfinite = xp.isfinite(xp.sum(X))
#     123 if first_pass_isfinite:
#     124     return
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:
